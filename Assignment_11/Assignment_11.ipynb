# %%
# !git clone https://github.com/Omkar1634/ERA_V2.git
# Out:
# fatal: destination path 'ERA_V2' already exists and is not an empty directory.

# %%
import os

print("Current Working Directory: ", os.getcwd())
os.chdir('/content/ERA_V2/Assignment_11')
print("Current Working Directory: ", os.getcwd())
# Out:
# Current Working Directory:  /content
# Current Working Directory:  /content/ERA_V2/Assignment_11

# %%
# !pip install grad-cam
# !pip install torch-lr-finder

# %%
import torch
from utils import train_transforms,test_transforms
from main import S_11
from models.resnet import ResNet18,ResNet34
from utils import MisclassificationVisualizer

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
classes = ('plane', 'car', 'bird', 'cat', 'deer','dog', 'frog', 'horse', 'ship', 'truck')
model = ResNet18().to(device)
trainer = S_11(model,train_transforms=train_transforms,test_transforms=test_transforms,classes=classes,scheduler_type='onecycle')
train_loader , test_loader = trainer.split_data()
# Out:
#  ==> Preparing data...
# Files already downloaded and verified
# Files already downloaded and verified

# %%
trainer.run()
# Out:
#  ==> Preparing data...
# Files already downloaded and verified
# Files already downloaded and verified
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/100 [00:00<?, ?it/s]
# Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 5.34E+00
# ==> Starting Training & Testing
# Epoch 1/20
# Loss=1.8995 Accuracy=27.08: 100%|██████████| 98/98 [00:38<00:00,  2.52it/s]
# Test set: Average loss: 1.8061, Accuracy: 3259/10000 (32.59%)
# Epoch 2/20
# Loss=1.5163 Accuracy=44.94: 100%|██████████| 98/98 [00:39<00:00,  2.50it/s]
# Test set: Average loss: 1.8610, Accuracy: 3509/10000 (35.09%)
# Epoch 3/20
# Loss=1.4747 Accuracy=47.62: 100%|██████████| 98/98 [00:39<00:00,  2.51it/s]
# ...

# %%
visualizer = MisclassificationVisualizer(model, device, test_loader, classes)
# Find and visualize misclassified images
visualizer.find_and_visualize_misclassified_images(num_images=10)

# %%
# Assuming target_layers is defined, e.g., for a ResNet model:
target_layers = [model.layer4[-1]]
visualizer.display_gradcam_output(target_layers=target_layers, number_of_samples=10)
